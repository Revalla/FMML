# %% [markdown]
# <a href="https://colab.research.google.com/github/Revalla/FMML/blob/main/FMML_M8L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-13 13:07:30--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   130MB/s    in 0.5s
#
# 2025-03-13 13:07:32 (130 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 13973  1702.08727v1  Algorithm learning is a core problem in artifi...    cs
# 21913  1502.05312v2  Unknown constraints arise in many types of exp...  stat
# 16517  1703.07090v1  Recurrent neural networks (RNNs), especially l...    cs
# 19932   1303.5422v1  Probabilistic reasoning systems combine differ...    cs
# 21679   0909.4395v1  This paper proposes an original approach to cl...  stat
# ...             ...                                                ...   ...
# 23202   1002.3985v1  In this paper, an algorithm is proposed for Im...    cs
# 38596   1111.3969v2  3D motion tracking is a critical task in many ...    cs
# 22601  1702.05777v5  Background: Statistical mechanics results (Dau...  stat
# 558    1502.06922v3  This paper develops a model that addresses sen...    cs
# 21992   1310.1562v4  We proposed a new statistical dependency measu...  stat
#
#                                                    title  year  \
# 13973  Improving the Neural GPU Architecture for Algo...  2017
# 21913  Predictive Entropy Search for Bayesian Optimiz...  2015
# 16517  Deep LSTM for Large Vocabulary Continuous Spee...  2017
# 19932       MESA: Maximum Entropy by Simulated Annealing  2013
# 21679         Initialization Free Graph Based Clustering  2009
# ...                                                  ...   ...
# 23202  Supervised Learning of Digital image restorati...  2010
# 38596  The Object Projection Feature Estimation Probl...  2011
# 22601  Exponentially vanishing sub-optimal local mini...  2017
# 558    Deep Sentence Embedding Using Long Short-Term ...  2015
# 21992          Dependence Measure for non-additive model  2013
#
#                                                 keywords
# 13973  [algorithm, artificial, intelligence, signific...
# 21913  [constraints, expensive, optimization, perform...
# 16517  [recurrent, especially, effective, sequential,...
# 19932  [probabilistic, reasoning, different, probabil...
# 21679  [component, including, estimation, constructio...
# ...                                                  ...
# 23202  [algorithm, restoration, algorithm, different,...
# 38596  [applications, techniques, knowledge, requirem...
# 22601  [background, statistical, mechanics, choromans...
# 558    [addresses, embedding, processing, recurrent, ...
# 21992  [statistical, dependency, dependency, variable...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 13973    [algorithm, artificial, intelligence, signific...
# 21913    [constraints, expensive, optimization, perform...
# 16517    [recurrent, especially, effective, sequential,...
# 19932    [probabilistic, reasoning, different, probabil...
# 21679    [component, including, estimation, constructio...
#                                ...
# 27116    [autonomous, environment, anticipate, anticipa...
# 20332    [commercial, alongside, customers, transportat...
# 9381     [propagation, algorithms, computational, infer...
# 11520    [efficient, representations, dimensional, succ...
# 22278    [identifying, objective, optimization, functio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8871 words.
# Out of those 4519 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7101e923-e1a3-449c-889f-8698df26d94d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7101e923-e1a3-449c-889f-8698df26d94d")) {                    Plotly.newPlot(                        "7101e923-e1a3-449c-889f-8698df26d94d",                        [{"x":["artificial","significant","improvements","technique","introduce","intelligence","multiplication","nonlinearities","architecture","automation","improving","implications","substantially","synthesizing","generalization","applicability","saturation","successful","algorithm","collected","approaches","promising","computing","performing","predictive","improvement","pathology","pathologies","decoupled","heuristic","favorably","demonstrate","effective","constrained","information","direction","synthetic","expensive","additionally","exploration","optimization","constraints","objective","benchmark","independently","encounter","performance","distillation","successfully","therefore","difficult","exponential","furthermore","distilled","competitive","beginning","segmental","framework","especially","introduced","streaming","recurrent","vocabulary","applications","continuous","conventional","character","impressive","capability","recognition","outperform","sequential","represented","probabilistic","precision","procedure","conflicts","directions","different","propositions","reasoning","arbitrary","variables","distribution","statements","simulated","contradictory","annealing","reliability","consequences","determine","probability","distributions","inference","trajectory","dimensional","astrophysics","application","presented","euclidean","initialize","approximations","assumption","measuring","including","component","usefulness","classical","detection","algorithms","satellite","thresholding","generalized","evaluating","divergence","clustering","approximately","distributed","construction","according","centroids","circumvent","corresponding","divergences","processing","estimation","initialization","similarity","estimated","satisfactorily","attempting","characteristics","interaction","interactions","available","structure","restricted","unavailable","predictions","demonstrates","neighborhoods","prediction","knowledge","boltzmann","background","discovery","alternative","additional","conclusion","situations","regarding","currently","illustrate","conducted","regularizations","simulations","resulting","spectrally","collaborative","homogeneous","laplacian","effectiveness","complexity","represents","smoothness","computational","spatially","alternating","attention","abundance","hyperspectral","multipliers","formulation","regularization","introduces","representation","convergence","statistical","iterative","asymptotic","decomposition","correlation","favorable","implementing","canonical","established","approximation","experiments","efficiently","correspond","observations","modifications","underlying","resurgence","formulated","sequences","expressed","significantly","represent","empirical"],"y":[123,254,107,238,309,81,9,6,237,13,118,25,31,14,104,45,5,77,833,70,428,140,115,84,72,135,8,3,1,58,21,546,247,68,657,65,143,74,79,62,346,159,168,204,39,4,911,8,99,143,137,41,159,4,114,8,3,543,99,109,23,138,37,429,97,103,51,16,61,348,96,71,80,165,90,120,13,48,774,6,127,74,121,201,14,62,9,10,28,22,70,168,90,192,25,166,1,268,196,29,8,37,62,30,267,112,23,116,374,578,13,16,67,65,17,139,22,97,67,117,3,7,122,2,285,217,26,157,61,3,8,94,79,72,314,341,54,7,97,53,6,217,329,18,78,56,96,122,15,55,51,60,69,69,4,46,152,2,36,25,17,237,210,42,18,290,28,32,163,13,20,19,93,88,82,348,138,148,67,22,56,69,13,16,27,41,118,588,156,23,77,24,113,2,33,106,34,286,123,141],"type":"bar"},{"x":["artificial","significant","improvements","techniqu ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4519,), (4519, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7991666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Invariant</span> <span style=''>Local</span> <span style='background-color:rgba(0, 255, 0, 0.6756756756756757);'>Descriptor</span> <span style=''>for</span> <span style=''>Event</span> <span style='background-color:rgba(0, 255, 0, 0.5535714285714286);'>Recognition</span> <span style=''>in</span> <span style=''>1D</span> <span style=''>Sensor</span> <span style=''>Signals</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>shape</span> <span style=''>based</span> <span style=''>time</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariant</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.6756756756756757);'>descriptor</span> <span style=''>for</span> <span style=''>1</span> <span style=''>D</span> <span style=''>sensor</span> <span style=''>signals</span> <span style=''>The</span> <span style=''>time</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>feature</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>use</span> <span style=''>feature</span> <span style=''>from</span> <span style=''>one</span> <span style=''>training</span> <span style=''>event</span> <span style=''>to</span> <span style=''>describe</span> <span style=''>events</span> <span style=''>of</span> <span style=''>the</span> <span style=''>same</span> <span style=''>semantic</span> <span style=''>class</span> <span style=''>which</span> <span style=''>may</span> <span style=''>take</span> <span style=''>place</span> <span style=''>over</span> <span style=''>varying</span> <span style=''>time</span> <span style=''>scales</span> <span style=''>such</span> <span style=''>as</span> <span style=''>walking</span> <span style=''>slow</span> <span style=''>and</span> <span style=''>walking</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Therefore</span> <span style=''>it</span> <span style=''>requires</span> <span style=''>less</span> <span style=''>training</span> <span style=''>set</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.6756756756756757);'>descriptor</span> <span style=''>takes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariant</span> <span style=''>location</span> <span style='background-color:rgba(0, 255, 0, 0.5780590717299579);'>detection</span> <span style=''>in</span> <span style=''>the</span> <span style=''>scale</span> <span style=''>space</span> <span style=''>theory</span> <span style=''>and</span> <span style=''>employs</span> <span style=''>a</span> <span style=''>high</span> <span style=''>level</span> <span style=''>shape</span> <span style=''>encoding</span> <span style=''>scheme</span> <span style=''>to</span> <span style=''>capture</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariant</span> <span style=''>local</span> <span style=''>features</span> <span style=''>of</span> <span style=''>events</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.6756756756756757);'>descriptor</span> <span style=''>a</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>with</span> <span style=''>R</span> <span style=''>metric</span> <span style=''>(SIC</span> <span style=''>R)</span> <span style=''>is</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>MEG</span> <span style=''>Decoding</span> <span style=''>Across</span> <span style=''>Subjects</span> <br/><br/><span style=''>Brain</span> <span style=''>decoding</span> <span style=''>is</span> <span style=''>a</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>paradigm</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neuroimaging</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>that</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicting</span> <span style=''>the</span> <span style=''>stimulus</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presented</span> <span style=''>to</span> <span style=''>the</span> <span style=''>subject</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>concurrent</span> <span style=''>brain</span> <span style=''>activity</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>make</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>at</span> <span style=''>the</span> <span style=''>group</span> <span style=''>level</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>straightforward</span> <span style=''>but</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sometimes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsuccessful</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>to</span> <span style=''>train</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>on</span> <span style=''>the</span> <span style=''>trials</span> <span style=''>of</span> <span style=''>a</span> <span style=''>group</span> <span style=''>of</span> <span style=''>subjects</span> <span style=''>and</span> <span style=''>then</span> <span style=''>to</span> <span style=''>test</span> <span style=''>it</span> <span style=''>on</span> <span style=''>unseen</span> <span style=''>trials</span> <span style=''>from</span> <span style=''>new</span> <span style=''>subjects</span> <span style=''>The</span> <span style=''>extreme</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficulty</span> <span style=''>is</span> <span style=''>related</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variability</span> <span style=''>across</span> <span style=''>the</span> <span style=''>subjects</span> <span style=''>We</span> <span style=''>call</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>decoding</span> <span style=''>across</span> <span style=''>subjects</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>address</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>decoding</span> <span style=''>across</span> <span style=''>subjects</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>magnetoencephalographic</span> <span style=''>(MEG)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>and</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contributions</span> <span style=''>first</span> <span style=''>we</span> <span style=''>formally</span> <span style=''>describe</span> <span style=''>the</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Bayesian</span> <span style=''>Sampling</span> <span style=''>Approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exploration</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.4125000000000001);'>Reinforcement</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>modular</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.4125000000000001);'>reinforcement</span> <span style=''>learning</span> <span style=''>that</span> <span style=''>uses</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.36738703339882134);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>over</span> <span style=''>models</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>BOSS</span> <span style=''>(Best</span> <span style=''>of</span> <span style=''>Sampled</span> <span style=''>Set)</span> <span style=''>drives</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploration</span> <span style=''>by</span> <span style=''>sampling</span> <span style=''>multiple</span> <span style=''>models</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5555555555555556);'>posterior</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selecting</span> <span style=''>actions</span> <span style=''>optimistically</span> <span style=''>It</span> <span style=''>extends</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>providing</span> <span style=''>a</span> <span style=''>rule</span> <span style=''>for</span> <span style=''>deciding</span> <span style=''>when</span> <span style=''>to</span> <span style=''>resample</span> <span style=''>and</span> <span style=''>how</span> <span style=''>to</span> <span style=''>combine</span> <span style=''>the</span> <span style=''>models</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>achieves</span> <span style=''>nearoptimal</span> <span style=''>reward</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>with</span> <span style=''>a</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>that</span> <span style=''>is</span> <span style=''>low</span> <span style=''>relative</span> <span style=''>to</span> <span style=''>the</span> <span style=''>speed</span> <span style=''>at</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5555555555555556);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>converges</span> <span style=''>during</span> <span style=''>learning</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>BOSS</span> <span style=''>performs</span> <span style=''>quite</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>favorably</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.4125000000000001);'>reinforcement</span> <span style=''>learning</span> <span style='background-color:rg ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Scalable</span> <span style=''>Multi</span> <span style=''>Output</span> <span style=''>Label</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>From</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classifier</span> <span style=''>Chains</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classifier</span> <span style=''>Trellises</span> <br/><br/><span style=''>Multi</span> <span style=''>output</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>tasks</span> <span style=''>such</span> <span style=''>as</span> <span style=''>multi</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>have</span> <span style=''>become</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasingly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>A</span> <span style=''>popular</span> <span style=''>method</span> <span style=''>for</span> <span style=''>multi</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>chains</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>are</span> <span style=''>cascaded</span> <span style=''>along</span> <span style=''>a</span> <span style=''>chain</span> <span style=''>thus</span> <span style=''>taking</span> <span style=''>into</span> <span style=''>account</span> <span style=''>inter</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependencies</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improving</span> <span style=''>the</span> <span style=''>overall</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>Several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>varieties</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>chain</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>and</span> <span style=''>many</span> <span style=''>of</span> <span style=''>them</span> <span style=''>perform</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>competitively</span> <span style=''>across</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style=''>datasets</span> <span style=''>However</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scalability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>limitations</span> <span style=''>become</span> <span style=''>apparent</span> <span style=''>on</span> <span style=''>larger</span> <span style=''>datasets</span> <span style=''>when</span> <span style=''>modeling</span> <span style=''>a</span> <span style=''>fully</span> <span style=''>cascaded</span> <span style=''>chain</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>the</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dis ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08497669415561133)
# 	representation (0.12477590534241664)
# 	processing (0.10218716385801363)
# 	automatic (0.0778056651129437)
# 	experimental (0.13624955181068482)
# 	segmentation (0.07708856220867695)
# 	recognition (0.12477590534241664)
# 	detection (0.13409824309788454)
# 	convolutional (0.13015417712441735)
# 	different (0.277518823951237)
#
# Some Statistics words are:
# 	distributions (0.1183490800596718)
# 	theoretical (0.1427150671307807)
# 	stochastic (0.1337642963699652)
# 	estimation (0.1670810542018896)
# 	statistical (0.14470412729985083)
# 	variables (0.14172053704624565)
# 	distribution (0.17802088513177525)
# 	inference (0.19393336648433615)
# 	dimensional (0.1859771258080557)
# 	regression (0.18150174042764794)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="133f21d2-fce8-46dd-9482-7b053d0a8619" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("133f21d2-fce8-46dd-9482-7b053d0a8619")) {                    Plotly.newPlot(                        "133f21d2-fce8-46dd-9482-7b053d0a8619",                        [{"x":["artificial","significant","improvements","technique","introduce","intelligence","multiplication","nonlinearities","architecture","automation","improving","implications","substantially","synthesizing","generalization","applicability","saturation","successful","algorithm","collected","approaches","promising","computing","performing","predictive","improvement","pathology","pathologies","decoupled","heuristic","favorably","demonstrate","effective","constrained","information","direction","synthetic","expensive","additionally","exploration","optimization","constraints","objective","benchmark","independently","encounter","performance","distillation","successfully","therefore","difficult","exponential","furthermore","distilled","competitive","beginning","segmental","framework","especially","introduced","streaming","recurrent","vocabulary","applications","continuous","conventional","character","impressive","capability","recognition","outperform","sequential","represented","probabilistic","precision","procedure","conflicts","directions","different","propositions","reasoning","arbitrary","variables","distribution","statements","simulated","contradictory","annealing","reliability","consequences","determine","probability","distributions","inference","trajectory","dimensional","astrophysics","application","presented","euclidean","initialize","approximations","assumption","measuring","including","component","usefulness","classical","detection","algorithms","satellite","thresholding","generalized","evaluating","divergence","clustering","approximately","distributed","construction","according","centroids","circumvent","corresponding","divergences","processing","estimation","initialization","similarity","estimated","satisfactorily","attempting","characteristics","interaction","interactions","available","structure","restricted","unavailable","predictions","demonstrates","neighborhoods","prediction","knowledge","boltzmann","background","discovery","alternative","additional","conclusion","situations","regarding","currently","illustrate","conducted","regularizations","simulations","resulting","spectrally","collaborative","homogeneous","laplacian","effectiveness","complexity","represents","smoothness","computational","spatially","alternating","attention","abundance","hyperspectral","multipliers","formulation","regularization","introduces","representation","convergence","statistical","iterative","asymptotic","decomposition","correlation","favorable","implementing","canonical","established","approximation","experiments","efficiently","correspond","observations","modifications","underlying","resurgence","formulated","sequences","expressed","significantly","represent","empirical","graphical","supervised","similarly","estimating","naturally","extension","searching","principled","unsupervised","denoising","exploited","generalizes","corruption","representations","relationship","implicitly","instances","relevance","misclassified","unlabeled","classifying","otherwise","legitimate","strategies","supervision","surrogate","correspondences","optimized","importance","particularly","contradicting","paramount","inconsistencies","similarities","optimally","consistent","integrated","unreliable","partially","estimates","relations","relationships","classification","initially","overcomes","structured","repeatedly","scenarios","dependency","inadequate","handwriting","efficient","seriously","difficulties","compre ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	neuroimage
# 	distributionally
# 	robustification
# 	stagewise
# 	regressions
# 	integrals
# 	thetastar
# 	irregularly
# 	missingness
# 	modulating
# 	parameterizes
# 	marginalized
# 	appropriateness
# 	robustifying
# 	increments
# 	supermodular
# 	integrable
# 	datastreams
# 	movielens
# 	amortization
# Some words which never appear in Statistics papers:
# 	contradictory
# 	destructive
# 	pedestrian
# 	injective
# 	registers
# 	argumentation
# 	algorithmically
# 	conversational
# 	unpredictable
# 	registering
# 	fuzziness
# 	biomedicine
# 	marketplace
# 	morphable
# 	threefold
# 	replanning
# 	abbreviations
# 	reconnaissance
# 	diagnoses
# 	hybridization

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.085562652349656e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.76
